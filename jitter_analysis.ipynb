# %% [markdown]
# # Jitter Analysis of Control Loop

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('15-12-2022-11-35-59.csv')

# %%
sampling_time = 1000000 # ns

# %%
jitter = df.diff().to_numpy() - sampling_time

# %% [markdown]
# Mean jitter

# %%
np.mean(jitter[1:])
# Out:
# -987780.0085401708

# %% [markdown]
# Standard deviation of the jitter

# %%
np.std(jitter[1:])
# Out:
# 65129565.07675493

# %%
fig, ax = plt.subplots()

ax.plot(jitter, marker='o', linestyle='None')

ax.set_xlabel('Samples')
ax.set_ylabel('Jitter [ns]')

fig.tight_layout()

# %%
fig, ax = plt.subplots()

ax.plot(jitter, marker='o', linestyle='None')

ax.set_xlabel('Samples')
ax.set_ylabel('Jitter [ns]')

ax.set_ylim(0, 400)

fig.tight_layout()

fig.savefig('jitter_ubuntu_22_04.pdf')
